# %% [markdown]
# ## Chicago 2016 Budget Ordinance - Positions and Salaries

# %% [markdown]
# Morgan Nomura, 7/17/17

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
chicago_data = pd.read_csv("data/Budget_-_2016_Budget_Ordinance_-_Positions_and_Salaries.csv", sep=',')

# %%
chicago_data
# Out:
#      FUND TYPE  DEPARTMENT CODE   DEPARTMENT DESCRIPTION FUND CODE  \
# 0        Local                1      OFFICE OF THE MAYOR      0100
# 1        Local                1      OFFICE OF THE MAYOR      0100
# 2        Local                1      OFFICE OF THE MAYOR      0100
# 3        Local                1      OFFICE OF THE MAYOR      0100
# 4        Local                1      OFFICE OF THE MAYOR      0100
# 5        Local                1      OFFICE OF THE MAYOR      0100
# 6        Local                1      OFFICE OF THE MAYOR      0100
# 7        Local                1      OFFICE OF THE MAYOR      0100
# 8        Local                1      OFFICE OF THE MAYOR      0100
# 9        Local                1      OFFICE OF THE MAYOR      0100
# 10       Local                1      OFFICE OF THE MAYOR      0100
# 11       Local                1      OFFICE OF THE MAYOR      0100
# 12       Local                1      OFFICE OF THE MAYOR      0100
# ...

# %%
### Which organization has the highest median budgeted pay
